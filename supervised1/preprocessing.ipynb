# %%
import librosa
import numpy as np
import os

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# %%
sample_rate = 22050
n_mels = 130
hop_length = 512
n_frames = 13
genres = ['blues', 'classical', 'country', 'disco', 'hiphop', 'jazz', 'metal', 'pop', 'reggae', 'rock']

# %%
def load_gtzan_data(data_path):
    X, y = [], []

    for genre in genres:
        genre_path = os.path.join(data_path, genre)
        for file in os.listdir(genre_path):
            if file.endswith('.wav'):
                file_path = os.path.join(genre_path, file)
                
                try:
                    audio, sr = librosa.load(file_path, sr=sample_rate)
                    mel_spec = librosa.feature.melspectrogram(y=audio,sr=sr,n_mels=n_mels,hop_length=hop_length)
                    mel_spec_db = librosa.power_to_db(mel_spec, ref=np.max)
                    if mel_spec_db.shape[1] >= n_frames:
                        mel_spec_db = mel_spec_db[:, :n_frames]
                    else:
                        mel_spec_db = np.pad(mel_spec_db, ((0, 0), (0, n_frames - mel_spec_db.shape[1])), mode='constant')


                    X.append(mel_spec_db)
                    y.append(genre)
                except Exception as e:
                    print(f"Error processing {file_path}: {e}")
    return np.array(X), np.array(y)

# %%
def augment_audio(audio, sr):

    audio_shifted = librosa.effects.pitch_shift(audio, n_steps=np.random.randint(-2, 2), sr=sr)
    audio_stretched = librosa.effects.time_stretch(audio, rate=np.random.uniform(0.8, 1.2))
    return audio_shifted, audio_stretched

# %%
import json


data_path = '../Data/data.json'

with open(data_path, "r") as fp:
    data = json.load(fp)

# Define X nd y
X = np.array(data["mfcc"])
y = np.array(data["genre_num"])
# Train-validation-test Split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.3, random_state=42, stratify=y_train)

X_train = X_train[..., np.newaxis]  # Add channel dimension
X_val = X_val[..., np.newaxis]      # Add channel dimension
X_test = X_test[..., np.newaxis]    # Add channel dimension

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, BatchNormalization, Dropout, GlobalAveragePooling2D, Dense

def build_fcnn(input_shape=(n_mels, n_frames, 1),num_classes=10):
    model = Sequential([
        #layer 1
        Conv2D(32, (3,3), activation='relu',padding='same',input_shape=input_shape),
        BatchNormalization(),
        MaxPooling2D((2, 2)),
        Dropout(0.3),

        #layer 2
        Conv2D(64, (3,3), activation='relu',padding='same'),
        BatchNormalization(),
        MaxPooling2D((2, 2)),
        Dropout(0.3),

        #layer 3
        Conv2D(128, (3,3), activation='relu',padding='same'),
        BatchNormalization(),   
        MaxPooling2D((2, 2)),
        Dropout(0.3),

        #layer 4
        Conv2D(128, (3,3), activation='relu',padding='same'),
        BatchNormalization(),
        GlobalAveragePooling2D(), #Replaces dense layers
        Dropout(0.3),
        Dense(64, activation='softmax')
    ])

    return model

# %%
model = build_fcnn()
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_8 (Conv2D)           (None, 130, 13, 32)       320
#
#  batch_normalization_8 (Bat  (None, 130, 13, 32)       128
#  chNormalization)
#
#  max_pooling2d_6 (MaxPoolin  (None, 65, 6, 32)         0
#  g2D)
#
#  dropout_8 (Dropout)         (None, 65, 6, 32)         0
#
#  conv2d_9 (Conv2D)           (None, 65, 6, 64)         18496
#
#  batch_normalization_9 (Bat  (None, 65, 6, 64)         256
#  chNormalization)
#
#  max_pooling2d_7 (MaxPoolin  (None, 32, 3, 64)         0
#  g2D)
#
#  dropout_9 (Dropout)         (None, 32, 3, 64)         0
#
#  conv2d_10 (Conv2D)          (None, 32, 3, 128)        73856
#
#  batch_normalization_10 (Ba  (None, 32, 3, 128)        512
#  tchNormalization)
#
#  max_pooling2d_8 (MaxPoolin  (None, 16, 1, 128)        0
#  g2D)
#
#  dropout_10 (Dropout)        (None, 16, 1, 128)        0
#
#  conv2d_11 (Conv2D)          (None, 16, 1, 128)        147584
#
#  batch_normalization_11 (Ba  (None, 16, 1, 128)        512
#  tchNormalization)
#
#  global_average_pooling2d_2  (None, 128)               0
#   (GlobalAveragePooling2D)
#
#  dropout_11 (Dropout)        (None, 128)               0
#
#  dense_2 (Dense)             (None, 64)                8256
#
# =================================================================
# Total params: 249920 (976.25 KB)
# Trainable params: 249216 (973.50 KB)
# Non-trainable params: 704 (2.75 KB)
# _________________________________________________________________

# %% [markdown]
# ## Training

# %%
from tensorflow.keras.callbacks import EarlyStopping

early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

history = model.fit(X_train, y_train,
                    validation_data=(X_val, y_val),
                    epochs=250,
                    batch_size=64,
                    callbacks=[early_stopping])
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print(f"Test_accuracy : {test_accuracy:.4f}")
# Out:
# Epoch 1/250
# 77/77 [==============================] - 8s 99ms/step - loss: 1.2248 - accuracy: 0.6070 - val_loss: 1.4316 - val_accuracy: 0.5122
# Epoch 2/250
# 77/77 [==============================] - 7s 96ms/step - loss: 1.0827 - accuracy: 0.6501 - val_loss: 1.1395 - val_accuracy: 0.6023
# Epoch 3/250
# 77/77 [==============================] - 7s 95ms/step - loss: 0.9417 - accuracy: 0.6916 - val_loss: 1.2390 - val_accuracy: 0.6037
# Epoch 4/250
# 77/77 [==============================] - 9s 114ms/step - loss: 0.8802 - accuracy: 0.7026 - val_loss: 0.9313 - val_accuracy: 0.7077
# Epoch 5/250
# 77/77 [==============================] - 8s 102ms/step - loss: 0.8142 - accuracy: 0.7159 - val_loss: 1.0929 - val_accuracy: 0.6643
# Epoch 6/250
# 77/77 [==============================] - 9s 113ms/step - loss: 0.7627 - accuracy: 0.7406 - val_loss: 1.1338 - val_accuracy: 0.6552
# Epoch 7/250
# 77/77 [==============================] - 9s 111ms/step - loss: 0.7048 - accuracy: 0.7509 - val_loss: 0.9467 - val_accuracy: 0.7115
# Epoch 8/250
# 77/77 [==============================] - 8s 107ms/step - loss: 0.6487 - accuracy: 0.7764 - val_loss: 0.8414 - val_accuracy: 0.7406
# Epoch 9/250
# 77/77 [==============================] - 8s 106ms/step - loss: 0.6451 - accuracy: 0.7807 - val_loss: 0.8856 - val_accuracy: 0.7363
# Epoch 10/250
# 77/77 [==============================] - 8s 103ms/step - loss: 0.6175 - accuracy: 0.7877 - val_loss: 0.7762 - val_accuracy: 0.7611
# Epoch 11/250
# 77/77 [==============================] - 9s 118ms/step - loss: 0.5795 - accuracy: 0.7962 - val_loss: 0.7490 - val_accuracy: 0.7663
# Epoch 12/250
# 77/77 [==============================] - 10s 127ms/step - loss: 0.5762 - accuracy: 0.8007 - val_loss: 0.6550 - val_accuracy: 0.8045
# Epoch 13/250
# 77/77 [==============================] - 9s 112ms/step - loss: 0.5393 - accuracy: 0.8105 - val_loss: 0.7628 - val_accuracy: 0.7725
# Epoch 14/250
# 77/77 [==============================] - 8s 100ms/step - loss: 0.4954 - accuracy: 0.8228 - val_loss: 0.6707 - val_accuracy: 0.7983
# Epoch 15/250
# 77/77 [==============================] - 8s 98ms/step - loss: 0.4730 - accuracy: 0.8402 - val_loss: 0.6594 - val_accuracy: 0.7845
# Epoch 16/250
# 77/77 [==============================] - 8s 107ms/step - loss: 0.4394 - accuracy: 0.8434 - val_loss: 0.5190 - val_accuracy: 0.8317
# Epoch 17/250
# 77/77 [==============================] - 8s 107ms/step - loss: 0.4444 - accuracy: 0.8457 - val_loss: 0.5644 - val_accuracy: 0.8216
# Epoch 18/250
# 77/77 [==============================] - 8s 103ms/step - loss: 0.4197 - accuracy: 0.8553 - val_loss: 0.6493 - val_accuracy: 0.7940
# Epoch 19/250
# 77/77 [==============================] - 9s 112ms/step - loss: 0.3944 - accuracy: 0.8612 - val_loss: 0.5703 - val_accuracy: 0.8197
# Epoch 20/250
# 77/77 [==============================] - 8s 109ms/step - loss: 0.4052 - accuracy: 0.8557 - val_loss: 0.7689 - val_accuracy: 0.7787
# Epoch 21/250
# 77/77 [==============================] - 7s 97ms/step - loss: 0.3806 - accuracy: 0.8674 - val_loss: 0.4964 - val_accuracy: 0.8541
# Epoch 22/250
# 77/77 [==============================] - 8s 110ms/step - loss: 0.3699 - accuracy: 0.8698 - val_loss: 0.5151 - val_accuracy: 0.8464
# Epoch 23/250
# 77/77 [==============================] - 10s 132ms/step - loss: 0.3585 - accuracy: 0.8794 - val_loss: 0.5691 - val_accuracy: 0.8340
# Epoch 24/250
# 77/77 [==============================] - 11s 144ms/step - loss: 0.3359 - accuracy: 0.8798 - val_loss: 0.5068 - val_accuracy: 0.8364
# Epoch 25/250
# 77/77 [==============================] - 8s 106ms/step - loss: 0.3346 - accuracy: 0.8788 - val_loss: 0.5929 - val_accuracy: 0.8226
# Epoch 26/250
# 77/77 [==============================] - 7s 95ms/step - loss: 0.3372 - accuracy: 0.8853 - val_loss: 0.5862 - val_accuracy: 0.8269
# Epoch 27/250
# 77/77 [==============================] - 7s 91ms/step - loss: 0.3098 - accuracy: 0.8933 - val_loss: 0.5972 - val_accuracy: 0.8226
# Epoch 28/250
# 77/77 [==============================] - 8s 100ms/step - loss: 0.3028 - accuracy: 0.8915 - val_loss: 0.4616 - val_accuracy: 0.8679
# Epoch 29/250
# 77/77 [==============================] - 8s 106ms/step - loss: 0.2839 - accuracy: 0.9037 - val_loss: 0.4909 - val_accuracy: 0.8522
# Epoch 30/250
# 77/77 [==============================] - 9s 111ms/step - loss: 0.2867 - accuracy: 0.8992 - val_loss: 0.4864 - val_accuracy: 0.8593
# Epoch 31/250
# 77/77 [==============================] - 8s 107ms/step - loss: 0.2797 - accuracy: 0.9003 - val_loss: 0.4709 - val_accuracy: 0.8574
# Epoch 32/250
# 77/77 [==============================] - 8s 105ms/step - loss: 0.2656 - accuracy: 0.9062 - val_loss: 0.5691 - val_accuracy: 0.8383
# Epoch 33/250
# 77/77 [==============================] - 8s 105ms/step - loss: 0.2644 - accuracy: 0.9111 - val_loss: 0.4895 - val_accuracy: 0.8546
# Epoch 34/250
# 77/77 [==============================] - 8s 102ms/step - loss: 0.2568 - accuracy: 0.9131 - val_loss: 0.4700 - val_accuracy: 0.8641
# Epoch 35/250
# 77/77 [==============================] - 8s 103ms/step - loss: 0.2560 - accuracy: 0.9068 - val_loss: 0.4892 - val_accuracy: 0.8517
# Epoch 36/250
# 77/77 [==============================] - 9s 114ms/step - loss: 0.2510 - accuracy: 0.9091 - val_loss: 0.4127 - val_accuracy: 0.8813
# Epoch 37/250
# 77/77 [==============================] - 9s 115ms/step - loss: 0.2236 - accuracy: 0.9232 - val_loss: 0.4362 - val_accuracy: 0.8703
# Epoch 38/250
# 77/77 [==============================] - 8s 108ms/step - loss: 0.2259 - accuracy: 0.9232 - val_loss: 0.5342 - val_accuracy: 0.8526
# Epoch 39/250
# 77/77 [==============================] - 8s 108ms/step - loss: 0.2113 - accuracy: 0.9236 - val_loss: 0.3996 - val_accuracy: 0.8794
# Epoch 40/250
# 77/77 [==============================] - 10s 131ms/step - loss: 0.2234 - accuracy: 0.9236 - val_loss: 0.5402 - val_accuracy: 0.8550
# Epoch 41/250
# 77/77 [==============================] - 9s 112ms/step - loss: 0.2254 - accuracy: 0.9172 - val_loss: 0.5109 - val_accuracy: 0.8531
# Epoch 42/250
# 77/77 [==============================] - 9s 113ms/step - loss: 0.2297 - accuracy: 0.9209 - val_loss: 0.4889 - val_accuracy: 0.8627
# Epoch 43/250
# 77/77 [==============================] - 8s 110ms/step - loss: 0.2212 - accuracy: 0.9207 - val_loss: 0.4681 - val_accuracy: 0.8712
# Epoch 44/250
# 77/77 [==============================] - 9s 114ms/step - loss: 0.2126 - accuracy: 0.9272 - val_loss: 0.4427 - val_accuracy: 0.8794
# Epoch 45/250
# 77/77 [==============================] - 9s 118ms/step - loss: 0.1983 - accuracy: 0.9309 - val_loss: 0.5674 - val_accuracy: 0.8383
# Epoch 46/250
# 77/77 [==============================] - 9s 113ms/step - loss: 0.2168 - accuracy: 0.9215 - val_loss: 0.5125 - val_accuracy: 0.8584
# Epoch 47/250
# 77/77 [==============================] - 8s 103ms/step - loss: 0.1838 - accuracy: 0.9403 - val_loss: 0.4282 - val_accuracy: 0.8727
# Epoch 48/250
# 77/77 [==============================] - 8s 109ms/step - loss: 0.1826 - accuracy: 0.9350 - val_loss: 0.4482 - val_accuracy: 0.8708
# Epoch 49/250
# 77/77 [==============================] - 8s 109ms/step - loss: 0.1898 - accuracy: 0.9346 - val_loss: 0.4350 - val_accuracy: 0.8884
# 94/94 [==============================] - 1s 15ms/step - loss: 0.4078 - accuracy: 0.8705
# Test_accuracy : 0.8705

# %%
model.save('../models/fcnn_melspec_gtzan.h5')
